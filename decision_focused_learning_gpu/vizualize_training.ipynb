# %%
import numpy as np 
import pandas as pd
import argparse
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict

input_dir = 'results/'
d = {'model' : [], 'epoch' : [] , 'loss' : [] , 'exp_train' : [] , 'exp_test' : [], 'dni_train' : [] , 'dni_test' : [], 'avg_dp' : [] , 'lr' : []}
l = []
with open(input_dir + 'df_training.txt', 'r') as file : 
    
    model = -1
    for line in file : 
        line = line.replace('\n', '').split(' | ')
        if len(line) > 2 :
            if line[0] == '0' :
                model += 1 
            l.append([model] + line) 
df = pd.DataFrame(l).astype(float)

fig, ax = plt.subplots(3,3,figsize = (20,15))
for i,ax in enumerate(ax.reshape(-1)) :
    sns.lineplot(data = df, x=1, y=i+2, hue=0, ax=ax)
fig.show()

# %%
# Out:
#         0    1           2            3           4           5         6  \
# 0     0.0  0.0   78.642097  2842.776855  184.642939  193.250088  381.1250
# 1     0.0  1.0   78.181206  2812.022949  194.964219  198.359882  395.7500
# 2     0.0  2.0   77.762054  3039.601807  223.984125  233.398945  423.0000
# 3     0.0  3.0   78.060692  2829.327637  222.287733  236.800297  423.0625
# 4     0.0  4.0   78.466629  2823.008545  225.126388  240.713905  426.8750
# ..    ...  ...         ...          ...         ...         ...       ...
# 245  14.0  0.0 -172.303802   170.422466  178.669685  337.750000  349.5000
# 246  15.0  0.0 -134.563660   142.658393  148.507473  269.500000  300.2500
# 247  16.0  0.0 -174.492249   169.931028  163.920395  371.812500  332.2500
# 248  17.0  0.0 -160.573532   176.217721  168.606430  356.687500  365.2500
# 249  18.0  0.0 -146.731125   167.928487  174.695667  337.250000  361.7500
#
#               7         8         9
# 0    355.750000  0.001298  0.000689
# ...

# %%
# Out:
# C:\Users\Mario\AppData\Local\Temp\ipykernel_11728\3808084017.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
